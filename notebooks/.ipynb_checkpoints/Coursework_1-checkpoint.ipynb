# %% [markdown]
# # Coursework 1
#
# This notebook is intended to be used as a starting point for your experiments. The instructions can be found in the instructions file located under spec/coursework1.pdf. The methods provided here are just helper functions. If you want more complex graphs such as side by side comparisons of different experiments you should learn more about matplotlib and implement them. Before each experiment remember to re-initialize neural network weights and reset the data providers so you get a properly initialized experiment. For each experiment try to keep most hyperparameters the same except the one under investigation so you can understand what the effects of each are.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def train_model_and_plot_stats(
        model, error, learning_rule, 
        train_data, valid_data, num_epochs, stats_interval, 
        notebook=True, fig_name = "baseline"):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')

    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    fig_1.savefig(fig_name + "1" + ".svg")
    fig_2.savefig(fig_name + "2" + ".svg")
    
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

# %%
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider

# Seed a random number generator
seed = 10102016 
rng = np.random.RandomState(seed)
batch_size = 100
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = MNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = MNISTDataProvider('valid', batch_size=batch_size, rng=rng)

# %% [markdown]
# ## Sigmoid

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# Baseline

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "sigmoid")

# %% [markdown]
# ## ReLU

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# RELU

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "relu")

# %% [markdown]
# ## Leaky ReLU

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# LEAKY RELU

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "leakyrelu")

# %% [markdown]
# ## ELU

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# ELU

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "elu")

# %% [markdown]
# ## SELU

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# SELU

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "selu")

# %% [markdown]
# # Part 2B

# %% [markdown]
# ## 3 Hidden Layers

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# RELU

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "3_elu")
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 1: 1.6s to complete
#     error(train)=2.58e-01, acc(train)=9.22e-01, error(valid)=2.40e-01, acc(valid)=9.30e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 2: 1.7s to complete
#     error(train)=1.83e-01, acc(train)=9.44e-01, error(valid)=1.76e-01, acc(valid)=9.47e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 3: 2.2s to complete
#     error(train)=1.40e-01, acc(train)=9.58e-01, error(valid)=1.41e-01, acc(valid)=9.59e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 4: 2.1s to complete
#     error(train)=1.20e-01, acc(train)=9.63e-01, error(valid)=1.30e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 5: 1.7s to complete
#     error(train)=1.04e-01, acc(train)=9.69e-01, error(valid)=1.21e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 6: 1.6s to complete
#     error(train)=8.51e-02, acc(train)=9.74e-01, error(valid)=1.07e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 7: 1.5s to complete
#     error(train)=7.77e-02, acc(train)=9.75e-01, error(valid)=1.01e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 8: 1.6s to complete
#     error(train)=6.40e-02, acc(train)=9.81e-01, error(valid)=9.15e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 9: 1.6s to complete
#     error(train)=5.50e-02, acc(train)=9.83e-01, error(valid)=8.78e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 10: 1.5s to complete
#     error(train)=5.47e-02, acc(train)=9.83e-01, error(valid)=9.04e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 11: 1.6s to complete
#     error(train)=4.35e-02, acc(train)=9.87e-01, error(valid)=8.15e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 12: 1.5s to complete
#     error(train)=4.04e-02, acc(train)=9.88e-01, error(valid)=8.42e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 13: 1.6s to complete
#     error(train)=3.76e-02, acc(train)=9.89e-01, error(valid)=8.17e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 14: 1.8s to complete
#     error(train)=3.21e-02, acc(train)=9.90e-01, error(valid)=8.71e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 15: 1.9s to complete
#     error(train)=2.76e-02, acc(train)=9.92e-01, error(valid)=8.25e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 16: 1.9s to complete
#     error(train)=2.81e-02, acc(train)=9.92e-01, error(valid)=8.39e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 17: 1.9s to complete
#     error(train)=2.28e-02, acc(train)=9.94e-01, error(valid)=8.15e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 18: 1.6s to complete
#     error(train)=2.12e-02, acc(train)=9.94e-01, error(valid)=8.45e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 19: 1.6s to complete
#     error(train)=1.75e-02, acc(train)=9.95e-01, error(valid)=8.09e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 20: 1.5s to complete
#     error(train)=1.64e-02, acc(train)=9.96e-01, error(valid)=8.51e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 21: 1.4s to complete
#     error(train)=1.30e-02, acc(train)=9.97e-01, error(valid)=8.45e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 22: 1.4s to complete
#     error(train)=1.13e-02, acc(train)=9.97e-01, error(valid)=8.22e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 23: 1.4s to complete
#     error(train)=1.20e-02, acc(train)=9.97e-01, error(valid)=9.04e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 24: 1.6s to complete
#     error(train)=1.22e-02, acc(train)=9.97e-01, error(valid)=9.16e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 25: 1.7s to complete
#     error(train)=8.56e-03, acc(train)=9.98e-01, error(valid)=9.04e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 26: 1.7s to complete
#     error(train)=6.79e-03, acc(train)=9.99e-01, error(valid)=9.14e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 27: 1.9s to complete
#     error(train)=6.87e-03, acc(train)=9.99e-01, error(valid)=9.37e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 28: 1.7s to complete
#     error(train)=5.86e-03, acc(train)=9.99e-01, error(valid)=9.62e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 29: 1.5s to complete
#     error(train)=4.06e-03, acc(train)=1.00e+00, error(valid)=9.42e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 30: 1.5s to complete
#     error(train)=3.84e-03, acc(train)=1.00e+00, error(valid)=9.16e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 31: 1.6s to complete
#     error(train)=3.97e-03, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 32: 1.5s to complete
#     error(train)=3.33e-03, acc(train)=1.00e+00, error(valid)=1.00e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 33: 1.4s to complete
#     error(train)=2.59e-03, acc(train)=1.00e+00, error(valid)=9.97e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 34: 1.5s to complete
#     error(train)=2.44e-03, acc(train)=1.00e+00, error(valid)=9.97e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 35: 1.6s to complete
#     error(train)=2.97e-03, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 36: 1.5s to complete
#     error(train)=1.73e-03, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 37: 1.7s to complete
#     error(train)=1.46e-03, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 38: 1.5s to complete
#     error(train)=1.42e-03, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 39: 1.6s to complete
#     error(train)=1.33e-03, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 40: 1.4s to complete
#     error(train)=1.31e-03, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 41: 1.5s to complete
#     error(train)=1.11e-03, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 42: 1.5s to complete
#     error(train)=1.01e-03, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 43: 1.7s to complete
#     error(train)=9.76e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 44: 1.5s to complete
#     error(train)=9.14e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 45: 1.5s to complete
#     error(train)=8.91e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 46: 1.6s to complete
#     error(train)=8.25e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 47: 1.6s to complete
#     error(train)=7.74e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 48: 1.5s to complete
#     error(train)=7.23e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 49: 1.5s to complete
#     error(train)=7.99e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 50: 1.4s to complete
#     error(train)=6.66e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 51: 1.4s to complete
#     error(train)=6.33e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 52: 1.4s to complete
#     error(train)=6.19e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 53: 1.4s to complete
#     error(train)=5.91e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 54: 1.4s to complete
#     error(train)=5.81e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 55: 1.6s to complete
#     error(train)=5.45e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 56: 1.7s to complete
#     error(train)=5.13e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 57: 1.6s to complete
#     error(train)=5.44e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 58: 1.6s to complete
#     error(train)=4.88e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 59: 1.5s to complete
#     error(train)=4.71e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 60: 1.7s to complete
#     error(train)=4.48e-04, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 61: 1.7s to complete
#     error(train)=4.33e-04, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 62: 1.6s to complete
#     error(train)=4.22e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 63: 1.7s to complete
#     error(train)=4.10e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 64: 1.7s to complete
#     error(train)=3.95e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 65: 1.7s to complete
#     error(train)=3.89e-04, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 66: 1.5s to complete
#     error(train)=3.88e-04, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 67: 1.5s to complete
#     error(train)=3.66e-04, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 68: 1.6s to complete
#     error(train)=3.57e-04, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 69: 1.7s to complete
#     error(train)=3.45e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 70: 1.6s to complete
#     error(train)=3.37e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 71: 1.6s to complete
#     error(train)=3.30e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 72: 1.7s to complete
#     error(train)=3.21e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 73: 1.5s to complete
#     error(train)=3.15e-04, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 74: 1.7s to complete
#     error(train)=3.04e-04, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 75: 1.5s to complete
#     error(train)=2.96e-04, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 76: 1.5s to complete
#     error(train)=2.93e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 77: 1.5s to complete
#     error(train)=2.83e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 78: 1.5s to complete
#     error(train)=2.81e-04, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 79: 1.5s to complete
#     error(train)=2.74e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 80: 1.5s to complete
#     error(train)=2.68e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 81: 1.5s to complete
#     error(train)=2.62e-04, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 82: 1.6s to complete
#     error(train)=2.53e-04, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 83: 1.5s to complete
#     error(train)=2.47e-04, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 84: 1.4s to complete
#     error(train)=2.46e-04, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 85: 1.7s to complete
#     error(train)=2.39e-04, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 86: 1.5s to complete
#     error(train)=2.34e-04, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 87: 1.4s to complete
#     error(train)=2.31e-04, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 88: 1.7s to complete
#     error(train)=2.28e-04, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 89: 1.6s to complete
#     error(train)=2.22e-04, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 90: 1.4s to complete
#     error(train)=2.18e-04, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 91: 1.4s to complete
#     error(train)=2.15e-04, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 92: 1.3s to complete
#     error(train)=2.08e-04, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 93: 1.4s to complete
#     error(train)=2.07e-04, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 94: 1.4s to complete
#     error(train)=2.04e-04, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 95: 1.4s to complete
#     error(train)=2.00e-04, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 96: 1.3s to complete
#     error(train)=1.94e-04, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 97: 1.4s to complete
#     error(train)=1.94e-04, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 98: 1.4s to complete
#     error(train)=1.91e-04, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 99: 1.6s to complete
#     error(train)=1.86e-04, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 100: 1.4s to complete
#     error(train)=1.83e-04, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00

# %% [markdown]
# ## 4 Hidden Layers

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# RELU

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "4_elu")
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 1: 1.7s to complete
#     error(train)=2.31e-01, acc(train)=9.32e-01, error(valid)=2.18e-01, acc(valid)=9.36e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 2: 1.7s to complete
#     error(train)=1.58e-01, acc(train)=9.52e-01, error(valid)=1.63e-01, acc(valid)=9.52e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 3: 1.8s to complete
#     error(train)=1.16e-01, acc(train)=9.65e-01, error(valid)=1.32e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 4: 1.6s to complete
#     error(train)=1.02e-01, acc(train)=9.69e-01, error(valid)=1.22e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 5: 1.7s to complete
#     error(train)=8.47e-02, acc(train)=9.73e-01, error(valid)=1.09e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 6: 1.7s to complete
#     error(train)=7.06e-02, acc(train)=9.78e-01, error(valid)=9.98e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 7: 1.6s to complete
#     error(train)=8.53e-02, acc(train)=9.71e-01, error(valid)=1.24e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 8: 1.6s to complete
#     error(train)=5.13e-02, acc(train)=9.84e-01, error(valid)=9.16e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 9: 1.9s to complete
#     error(train)=4.89e-02, acc(train)=9.84e-01, error(valid)=9.37e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 10: 1.8s to complete
#     error(train)=3.94e-02, acc(train)=9.88e-01, error(valid)=8.54e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 11: 1.6s to complete
#     error(train)=4.08e-02, acc(train)=9.87e-01, error(valid)=9.00e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 12: 1.6s to complete
#     error(train)=3.69e-02, acc(train)=9.89e-01, error(valid)=8.96e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 13: 1.6s to complete
#     error(train)=2.58e-02, acc(train)=9.92e-01, error(valid)=8.11e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 14: 1.7s to complete
#     error(train)=2.27e-02, acc(train)=9.94e-01, error(valid)=8.40e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 15: 1.7s to complete
#     error(train)=2.91e-02, acc(train)=9.90e-01, error(valid)=9.25e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 16: 2.0s to complete
#     error(train)=2.03e-02, acc(train)=9.94e-01, error(valid)=8.45e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 17: 1.8s to complete
#     error(train)=1.91e-02, acc(train)=9.94e-01, error(valid)=8.75e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 18: 1.7s to complete
#     error(train)=1.99e-02, acc(train)=9.94e-01, error(valid)=9.11e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 19: 1.8s to complete
#     error(train)=1.39e-02, acc(train)=9.96e-01, error(valid)=8.62e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 20: 2.0s to complete
#     error(train)=1.29e-02, acc(train)=9.96e-01, error(valid)=9.29e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 21: 1.6s to complete
#     error(train)=1.03e-02, acc(train)=9.97e-01, error(valid)=9.12e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 22: 1.7s to complete
#     error(train)=6.89e-03, acc(train)=9.98e-01, error(valid)=9.06e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 23: 1.6s to complete
#     error(train)=8.83e-03, acc(train)=9.97e-01, error(valid)=9.74e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 24: 1.9s to complete
#     error(train)=7.52e-03, acc(train)=9.98e-01, error(valid)=9.59e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 25: 1.6s to complete
#     error(train)=5.45e-03, acc(train)=9.99e-01, error(valid)=9.97e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 26: 2.0s to complete
#     error(train)=2.64e-03, acc(train)=1.00e+00, error(valid)=9.68e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 27: 1.9s to complete
#     error(train)=3.10e-03, acc(train)=1.00e+00, error(valid)=9.90e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 28: 1.8s to complete
#     error(train)=2.81e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 29: 1.7s to complete
#     error(train)=1.50e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 30: 1.8s to complete
#     error(train)=1.58e-03, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 31: 1.6s to complete
#     error(train)=1.11e-03, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 32: 1.8s to complete
#     error(train)=9.76e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 33: 1.7s to complete
#     error(train)=1.05e-03, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 34: 1.7s to complete
#     error(train)=7.89e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 35: 1.7s to complete
#     error(train)=8.64e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 36: 1.8s to complete
#     error(train)=6.91e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 37: 1.7s to complete
#     error(train)=6.01e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 38: 1.8s to complete
#     error(train)=6.05e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 39: 1.8s to complete
#     error(train)=5.41e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 40: 1.8s to complete
#     error(train)=5.04e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 41: 1.9s to complete
#     error(train)=4.72e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 42: 1.7s to complete
#     error(train)=4.80e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 43: 1.8s to complete
#     error(train)=4.17e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 44: 1.8s to complete
#     error(train)=3.90e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 45: 1.7s to complete
#     error(train)=3.84e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 46: 1.9s to complete
#     error(train)=3.60e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 47: 1.7s to complete
#     error(train)=3.48e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 48: 1.7s to complete
#     error(train)=3.25e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 49: 1.7s to complete
#     error(train)=3.15e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 50: 1.8s to complete
#     error(train)=3.07e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 51: 1.8s to complete
#     error(train)=3.07e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 52: 1.7s to complete
#     error(train)=2.82e-04, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 53: 1.8s to complete
#     error(train)=2.72e-04, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 54: 1.7s to complete
#     error(train)=2.66e-04, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 55: 1.7s to complete
#     error(train)=2.61e-04, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 56: 1.7s to complete
#     error(train)=2.45e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 57: 1.6s to complete
#     error(train)=2.39e-04, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 58: 2.3s to complete
#     error(train)=2.26e-04, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 59: 2.2s to complete
#     error(train)=2.25e-04, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 60: 2.2s to complete
#     error(train)=2.13e-04, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 61: 2.1s to complete
#     error(train)=2.09e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 62: 1.8s to complete
#     error(train)=2.07e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 63: 1.7s to complete
#     error(train)=1.96e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 64: 1.8s to complete
#     error(train)=1.93e-04, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 65: 1.8s to complete
#     error(train)=1.85e-04, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 66: 1.7s to complete
#     error(train)=1.81e-04, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 67: 1.7s to complete
#     error(train)=1.78e-04, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 68: 1.7s to complete
#     error(train)=1.75e-04, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 69: 1.8s to complete
#     error(train)=1.68e-04, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 70: 1.7s to complete
#     error(train)=1.63e-04, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 71: 1.7s to complete
#     error(train)=1.60e-04, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 72: 1.8s to complete
#     error(train)=1.55e-04, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 73: 1.7s to complete
#     error(train)=1.53e-04, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 74: 1.7s to complete
#     error(train)=1.49e-04, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 75: 1.7s to complete
#     error(train)=1.45e-04, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 76: 1.8s to complete
#     error(train)=1.42e-04, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 77: 1.7s to complete
#     error(train)=1.38e-04, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 78: 1.7s to complete
#     error(train)=1.35e-04, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 79: 1.7s to complete
#     error(train)=1.34e-04, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 80: 1.7s to complete
#     error(train)=1.31e-04, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 81: 1.8s to complete
#     error(train)=1.28e-04, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 82: 1.6s to complete
#     error(train)=1.26e-04, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 83: 1.6s to complete
#     error(train)=1.23e-04, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 84: 1.9s to complete
#     error(train)=1.20e-04, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 85: 1.7s to complete
#     error(train)=1.19e-04, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 86: 1.7s to complete
#     error(train)=1.16e-04, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 87: 1.7s to complete
#     error(train)=1.14e-04, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 88: 1.7s to complete
#     error(train)=1.12e-04, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 89: 1.7s to complete
#     error(train)=1.10e-04, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 90: 1.8s to complete
#     error(train)=1.08e-04, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 91: 1.6s to complete
#     error(train)=1.06e-04, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 92: 1.7s to complete
#     error(train)=1.04e-04, acc(train)=1.00e+00, error(valid)=1.38e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 93: 1.7s to complete
#     error(train)=1.03e-04, acc(train)=1.00e+00, error(valid)=1.38e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 94: 1.6s to complete
#     error(train)=1.01e-04, acc(train)=1.00e+00, error(valid)=1.38e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 95: 1.7s to complete
#     error(train)=9.88e-05, acc(train)=1.00e+00, error(valid)=1.39e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 96: 1.7s to complete
#     error(train)=9.76e-05, acc(train)=1.00e+00, error(valid)=1.39e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 97: 1.7s to complete
#     error(train)=9.57e-05, acc(train)=1.00e+00, error(valid)=1.39e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 98: 1.7s to complete
#     error(train)=9.43e-05, acc(train)=1.00e+00, error(valid)=1.40e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 99: 1.7s to complete
#     error(train)=9.28e-05, acc(train)=1.00e+00, error(valid)=1.40e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 100: 1.7s to complete
#     error(train)=9.20e-05, acc(train)=1.00e+00, error(valid)=1.40e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00

# %% [markdown]
# ## 5 Hidden Layers

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# RELU

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "5_elu")
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 1: 2.1s to complete
#     error(train)=2.03e-01, acc(train)=9.39e-01, error(valid)=1.94e-01, acc(valid)=9.42e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 2: 2.0s to complete
#     error(train)=1.40e-01, acc(train)=9.57e-01, error(valid)=1.42e-01, acc(valid)=9.59e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 3: 2.1s to complete
#     error(train)=1.31e-01, acc(train)=9.58e-01, error(valid)=1.41e-01, acc(valid)=9.59e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 4: 2.1s to complete
#     error(train)=9.39e-02, acc(train)=9.71e-01, error(valid)=1.12e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 5: 2.0s to complete
#     error(train)=7.48e-02, acc(train)=9.76e-01, error(valid)=1.00e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 6: 1.9s to complete
#     error(train)=7.68e-02, acc(train)=9.76e-01, error(valid)=1.03e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 7: 1.9s to complete
#     error(train)=5.82e-02, acc(train)=9.82e-01, error(valid)=9.26e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 8: 2.0s to complete
#     error(train)=5.28e-02, acc(train)=9.83e-01, error(valid)=9.69e-02, acc(valid)=9.69e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 9: 2.0s to complete
#     error(train)=4.24e-02, acc(train)=9.87e-01, error(valid)=8.48e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 10: 2.0s to complete
#     error(train)=4.20e-02, acc(train)=9.87e-01, error(valid)=8.77e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 11: 2.0s to complete
#     error(train)=3.08e-02, acc(train)=9.90e-01, error(valid)=8.60e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 12: 2.1s to complete
#     error(train)=2.51e-02, acc(train)=9.93e-01, error(valid)=8.28e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 13: 1.9s to complete
#     error(train)=2.35e-02, acc(train)=9.93e-01, error(valid)=8.42e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 14: 1.9s to complete
#     error(train)=2.05e-02, acc(train)=9.94e-01, error(valid)=8.96e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 15: 2.0s to complete
#     error(train)=1.77e-02, acc(train)=9.95e-01, error(valid)=8.41e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 16: 2.0s to complete
#     error(train)=1.33e-02, acc(train)=9.96e-01, error(valid)=9.18e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 17: 2.2s to complete
#     error(train)=1.16e-02, acc(train)=9.97e-01, error(valid)=9.13e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 18: 2.1s to complete
#     error(train)=1.28e-02, acc(train)=9.96e-01, error(valid)=9.02e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 19: 2.0s to complete
#     error(train)=8.14e-03, acc(train)=9.98e-01, error(valid)=9.23e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 20: 2.0s to complete
#     error(train)=1.15e-02, acc(train)=9.96e-01, error(valid)=9.91e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 21: 2.0s to complete
#     error(train)=1.97e-02, acc(train)=9.93e-01, error(valid)=1.16e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 22: 2.2s to complete
#     error(train)=5.46e-03, acc(train)=9.99e-01, error(valid)=9.46e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 23: 2.0s to complete
#     error(train)=3.75e-03, acc(train)=9.99e-01, error(valid)=9.77e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 24: 1.8s to complete
#     error(train)=2.84e-03, acc(train)=1.00e+00, error(valid)=9.85e-02, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 25: 1.9s to complete
#     error(train)=3.36e-03, acc(train)=9.99e-01, error(valid)=1.03e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 26: 1.8s to complete
#     error(train)=1.47e-03, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 27: 1.9s to complete
#     error(train)=3.15e-03, acc(train)=9.99e-01, error(valid)=1.08e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 28: 2.1s to complete
#     error(train)=1.02e-03, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 29: 2.4s to complete
#     error(train)=1.01e-03, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 30: 2.0s to complete
#     error(train)=6.87e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 31: 1.8s to complete
#     error(train)=5.78e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 32: 1.9s to complete
#     error(train)=5.99e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 33: 1.8s to complete
#     error(train)=4.95e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 34: 1.8s to complete
#     error(train)=4.41e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 35: 1.9s to complete
#     error(train)=4.08e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 36: 1.9s to complete
#     error(train)=3.70e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 37: 1.8s to complete
#     error(train)=3.41e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 38: 1.8s to complete
#     error(train)=3.17e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 39: 2.0s to complete
#     error(train)=3.03e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 40: 1.9s to complete
#     error(train)=2.81e-04, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 41: 1.8s to complete
#     error(train)=2.69e-04, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 42: 2.2s to complete
#     error(train)=2.54e-04, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 43: 2.2s to complete
#     error(train)=2.42e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 44: 2.0s to complete
#     error(train)=2.28e-04, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 45: 1.8s to complete
#     error(train)=2.19e-04, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 46: 1.8s to complete
#     error(train)=2.08e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 47: 2.1s to complete
#     error(train)=2.02e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 48: 2.0s to complete
#     error(train)=1.97e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 49: 1.9s to complete
#     error(train)=1.86e-04, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 50: 1.9s to complete
#     error(train)=1.76e-04, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 51: 1.8s to complete
#     error(train)=1.71e-04, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 52: 1.9s to complete
#     error(train)=1.67e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 53: 1.8s to complete
#     error(train)=1.60e-04, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 54: 1.8s to complete
#     error(train)=1.52e-04, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 55: 2.0s to complete
#     error(train)=1.47e-04, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 56: 2.1s to complete
#     error(train)=1.42e-04, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 57: 2.2s to complete
#     error(train)=1.44e-04, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 58: 1.9s to complete
#     error(train)=1.34e-04, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 59: 2.0s to complete
#     error(train)=1.31e-04, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 60: 2.4s to complete
#     error(train)=1.26e-04, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 61: 1.9s to complete
#     error(train)=1.23e-04, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 62: 1.9s to complete
#     error(train)=1.19e-04, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 63: 1.8s to complete
#     error(train)=1.19e-04, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 64: 1.8s to complete
#     error(train)=1.12e-04, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 65: 1.8s to complete
#     error(train)=1.10e-04, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 66: 1.9s to complete
#     error(train)=1.07e-04, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 67: 2.0s to complete
#     error(train)=1.05e-04, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 68: 2.2s to complete
#     error(train)=1.02e-04, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 69: 2.0s to complete
#     error(train)=9.89e-05, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 70: 2.6s to complete
#     error(train)=9.65e-05, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 71: 2.1s to complete
#     error(train)=9.50e-05, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 72: 1.9s to complete
#     error(train)=9.24e-05, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 73: 1.8s to complete
#     error(train)=9.02e-05, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 74: 2.0s to complete
#     error(train)=8.83e-05, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 75: 2.2s to complete
#     error(train)=8.64e-05, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 76: 1.8s to complete
#     error(train)=8.43e-05, acc(train)=1.00e+00, error(valid)=1.38e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 77: 2.1s to complete
#     error(train)=8.31e-05, acc(train)=1.00e+00, error(valid)=1.38e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 78: 1.8s to complete
#     error(train)=8.08e-05, acc(train)=1.00e+00, error(valid)=1.38e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 79: 1.9s to complete
#     error(train)=7.93e-05, acc(train)=1.00e+00, error(valid)=1.39e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 80: 2.1s to complete
#     error(train)=7.80e-05, acc(train)=1.00e+00, error(valid)=1.39e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 81: 1.8s to complete
#     error(train)=7.66e-05, acc(train)=1.00e+00, error(valid)=1.40e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 82: 2.3s to complete
#     error(train)=7.46e-05, acc(train)=1.00e+00, error(valid)=1.40e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 83: 2.5s to complete
#     error(train)=7.35e-05, acc(train)=1.00e+00, error(valid)=1.40e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 84: 2.5s to complete
#     error(train)=7.18e-05, acc(train)=1.00e+00, error(valid)=1.41e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 85: 2.0s to complete
#     error(train)=7.08e-05, acc(train)=1.00e+00, error(valid)=1.41e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 86: 1.9s to complete
#     error(train)=6.94e-05, acc(train)=1.00e+00, error(valid)=1.41e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 87: 2.2s to complete
#     error(train)=6.80e-05, acc(train)=1.00e+00, error(valid)=1.42e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 88: 1.9s to complete
#     error(train)=6.72e-05, acc(train)=1.00e+00, error(valid)=1.42e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 89: 1.8s to complete
#     error(train)=6.58e-05, acc(train)=1.00e+00, error(valid)=1.42e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 90: 1.9s to complete
#     error(train)=6.45e-05, acc(train)=1.00e+00, error(valid)=1.43e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 91: 1.9s to complete
#     error(train)=6.33e-05, acc(train)=1.00e+00, error(valid)=1.43e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 92: 1.9s to complete
#     error(train)=6.25e-05, acc(train)=1.00e+00, error(valid)=1.43e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 93: 2.0s to complete
#     error(train)=6.13e-05, acc(train)=1.00e+00, error(valid)=1.43e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 94: 1.9s to complete
#     error(train)=6.03e-05, acc(train)=1.00e+00, error(valid)=1.43e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 95: 2.0s to complete
#     error(train)=5.92e-05, acc(train)=1.00e+00, error(valid)=1.44e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 96: 2.2s to complete
#     error(train)=5.82e-05, acc(train)=1.00e+00, error(valid)=1.44e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 97: 1.9s to complete
#     error(train)=5.74e-05, acc(train)=1.00e+00, error(valid)=1.44e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 98: 2.0s to complete
#     error(train)=5.66e-05, acc(train)=1.00e+00, error(valid)=1.45e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 99: 2.1s to complete
#     error(train)=5.56e-05, acc(train)=1.00e+00, error(valid)=1.45e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 100: 1.9s to complete
#     error(train)=5.50e-05, acc(train)=1.00e+00, error(valid)=1.45e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00

# %% [markdown]
# ## 6 Hidden Layers

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# RELU

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "6_elu")

# %% [markdown]
# ## 7 Hidden Layers

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# RELU

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "7_elu")
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 1: 2.5s to complete
#     error(train)=2.05e-01, acc(train)=9.38e-01, error(valid)=1.93e-01, acc(valid)=9.42e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 2: 2.6s to complete
#     error(train)=1.30e-01, acc(train)=9.60e-01, error(valid)=1.38e-01, acc(valid)=9.60e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 3: 2.5s to complete
#     error(train)=1.02e-01, acc(train)=9.68e-01, error(valid)=1.10e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 4: 2.3s to complete
#     error(train)=8.09e-02, acc(train)=9.74e-01, error(valid)=1.09e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 5: 2.3s to complete
#     error(train)=7.51e-02, acc(train)=9.76e-01, error(valid)=1.02e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 6: 2.3s to complete
#     error(train)=6.07e-02, acc(train)=9.81e-01, error(valid)=9.39e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 7: 2.6s to complete
#     error(train)=5.60e-02, acc(train)=9.82e-01, error(valid)=9.86e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 8: 2.3s to complete
#     error(train)=4.73e-02, acc(train)=9.85e-01, error(valid)=9.18e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 9: 2.4s to complete
#     error(train)=4.41e-02, acc(train)=9.85e-01, error(valid)=9.03e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 10: 2.5s to complete
#     error(train)=3.27e-02, acc(train)=9.90e-01, error(valid)=8.81e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 11: 2.5s to complete
#     error(train)=3.38e-02, acc(train)=9.89e-01, error(valid)=8.75e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 12: 2.5s to complete
#     error(train)=2.68e-02, acc(train)=9.92e-01, error(valid)=9.08e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 13: 2.4s to complete
#     error(train)=2.86e-02, acc(train)=9.91e-01, error(valid)=9.51e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 14: 2.4s to complete
#     error(train)=1.77e-02, acc(train)=9.94e-01, error(valid)=8.27e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 15: 2.4s to complete
#     error(train)=2.25e-02, acc(train)=9.92e-01, error(valid)=9.89e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 16: 2.3s to complete
#     error(train)=1.92e-02, acc(train)=9.94e-01, error(valid)=9.20e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 17: 2.4s to complete
#     error(train)=1.16e-02, acc(train)=9.96e-01, error(valid)=8.83e-02, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 18: 2.5s to complete
#     error(train)=1.09e-02, acc(train)=9.97e-01, error(valid)=9.55e-02, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 19: 2.4s to complete
#     error(train)=1.32e-02, acc(train)=9.96e-01, error(valid)=1.01e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 20: 2.3s to complete
#     error(train)=1.12e-02, acc(train)=9.96e-01, error(valid)=1.01e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 21: 2.3s to complete
#     error(train)=1.69e-02, acc(train)=9.94e-01, error(valid)=1.10e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 22: 2.5s to complete
#     error(train)=7.21e-03, acc(train)=9.98e-01, error(valid)=1.00e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 23: 2.4s to complete
#     error(train)=3.21e-03, acc(train)=9.99e-01, error(valid)=1.01e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 24: 2.8s to complete
#     error(train)=4.63e-03, acc(train)=9.99e-01, error(valid)=1.02e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 25: 2.8s to complete
#     error(train)=3.50e-02, acc(train)=9.89e-01, error(valid)=1.61e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 26: 2.8s to complete
#     error(train)=2.19e-02, acc(train)=9.94e-01, error(valid)=1.21e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 27: 2.8s to complete
#     error(train)=1.63e-02, acc(train)=9.94e-01, error(valid)=1.11e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 28: 2.7s to complete
#     error(train)=5.06e-03, acc(train)=9.98e-01, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 29: 2.7s to complete
#     error(train)=1.32e-03, acc(train)=1.00e+00, error(valid)=1.01e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 30: 2.9s to complete
#     error(train)=7.39e-04, acc(train)=1.00e+00, error(valid)=1.00e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 31: 2.8s to complete
#     error(train)=4.46e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 32: 2.6s to complete
#     error(train)=8.92e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 33: 2.8s to complete
#     error(train)=3.08e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 34: 2.7s to complete
#     error(train)=2.59e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 35: 2.4s to complete
#     error(train)=2.36e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 36: 2.3s to complete
#     error(train)=2.23e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 37: 2.3s to complete
#     error(train)=1.97e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.83e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 38: 2.2s to complete
#     error(train)=1.82e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 39: 2.2s to complete
#     error(train)=1.66e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 40: 2.2s to complete
#     error(train)=1.53e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 41: 2.3s to complete
#     error(train)=1.44e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 42: 2.3s to complete
#     error(train)=1.36e-04, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 43: 2.2s to complete
#     error(train)=1.28e-04, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 44: 2.3s to complete
#     error(train)=1.22e-04, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 45: 2.2s to complete
#     error(train)=1.14e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 46: 2.3s to complete
#     error(train)=1.09e-04, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 47: 2.2s to complete
#     error(train)=1.04e-04, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 48: 2.3s to complete
#     error(train)=9.90e-05, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 49: 2.2s to complete
#     error(train)=9.47e-05, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 50: 2.4s to complete
#     error(train)=9.08e-05, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 51: 2.3s to complete
#     error(train)=8.73e-05, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 52: 2.2s to complete
#     error(train)=8.39e-05, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 53: 2.2s to complete
#     error(train)=8.04e-05, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.83e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 54: 2.2s to complete
#     error(train)=7.74e-05, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 55: 2.2s to complete
#     error(train)=7.50e-05, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 56: 2.2s to complete
#     error(train)=7.25e-05, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 57: 2.2s to complete
#     error(train)=6.96e-05, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 58: 2.2s to complete
#     error(train)=6.78e-05, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 59: 2.2s to complete
#     error(train)=6.53e-05, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 60: 2.3s to complete
#     error(train)=6.33e-05, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 61: 2.2s to complete
#     error(train)=6.14e-05, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 62: 2.2s to complete
#     error(train)=5.97e-05, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.83e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 63: 2.2s to complete
#     error(train)=5.80e-05, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 64: 2.2s to complete
#     error(train)=5.64e-05, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.83e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 65: 2.2s to complete
#     error(train)=5.51e-05, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 66: 2.2s to complete
#     error(train)=5.33e-05, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 67: 2.2s to complete
#     error(train)=5.18e-05, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 68: 2.2s to complete
#     error(train)=5.05e-05, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 69: 2.2s to complete
#     error(train)=4.92e-05, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 70: 2.2s to complete
#     error(train)=4.80e-05, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 71: 2.2s to complete
#     error(train)=4.68e-05, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.83e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 72: 2.2s to complete
#     error(train)=4.59e-05, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 73: 2.2s to complete
#     error(train)=4.47e-05, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 74: 2.2s to complete
#     error(train)=4.36e-05, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 75: 2.2s to complete
#     error(train)=4.27e-05, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 76: 2.2s to complete
#     error(train)=4.19e-05, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 77: 2.2s to complete
#     error(train)=4.09e-05, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 78: 2.2s to complete
#     error(train)=3.99e-05, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 79: 2.4s to complete
#     error(train)=3.91e-05, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.83e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 80: 2.5s to complete
#     error(train)=3.83e-05, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 81: 2.3s to complete
#     error(train)=3.76e-05, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 82: 2.3s to complete
#     error(train)=3.68e-05, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 83: 2.8s to complete
#     error(train)=3.61e-05, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 84: 3.1s to complete
#     error(train)=3.54e-05, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 85: 2.7s to complete
#     error(train)=3.47e-05, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 86: 2.2s to complete
#     error(train)=3.41e-05, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 87: 2.4s to complete
#     error(train)=3.35e-05, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 88: 2.4s to complete
#     error(train)=3.28e-05, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 89: 2.3s to complete
#     error(train)=3.23e-05, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 90: 2.3s to complete
#     error(train)=3.17e-05, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 91: 2.3s to complete
#     error(train)=3.12e-05, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 92: 2.6s to complete
#     error(train)=3.06e-05, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 93: 2.6s to complete
#     error(train)=3.01e-05, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 94: 2.7s to complete
#     error(train)=2.96e-05, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 95: 3.2s to complete
#     error(train)=2.91e-05, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 96: 3.3s to complete
#     error(train)=2.87e-05, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 97: 2.8s to complete
#     error(train)=2.82e-05, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 98: 2.8s to complete
#     error(train)=2.77e-05, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 99: 2.7s to complete
#     error(train)=2.73e-05, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 100: 2.8s to complete
#     error(train)=2.69e-05, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.82e-01, params_penalty=0.00e+00

# %% [markdown]
# ## 8 Hidden Layers

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# RELU

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "8_elu")
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 1: 2.7s to complete
#     error(train)=1.86e-01, acc(train)=9.43e-01, error(valid)=1.84e-01, acc(valid)=9.46e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 2: 2.6s to complete
#     error(train)=1.22e-01, acc(train)=9.62e-01, error(valid)=1.29e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 3: 2.6s to complete
#     error(train)=1.11e-01, acc(train)=9.65e-01, error(valid)=1.22e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 4: 2.5s to complete
#     error(train)=8.04e-02, acc(train)=9.75e-01, error(valid)=1.06e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 5: 2.5s to complete
#     error(train)=6.17e-02, acc(train)=9.80e-01, error(valid)=9.61e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 6: 2.5s to complete
#     error(train)=8.88e-02, acc(train)=9.70e-01, error(valid)=1.30e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 7: 2.6s to complete
#     error(train)=5.87e-02, acc(train)=9.81e-01, error(valid)=9.99e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 8: 2.5s to complete
#     error(train)=3.99e-02, acc(train)=9.87e-01, error(valid)=8.68e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 9: 2.5s to complete
#     error(train)=3.69e-02, acc(train)=9.89e-01, error(valid)=8.89e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 10: 2.5s to complete
#     error(train)=3.49e-02, acc(train)=9.89e-01, error(valid)=9.27e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 11: 2.5s to complete
#     error(train)=2.71e-02, acc(train)=9.91e-01, error(valid)=8.66e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 12: 2.9s to complete
#     error(train)=3.37e-02, acc(train)=9.88e-01, error(valid)=9.44e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 13: 3.1s to complete
#     error(train)=2.08e-02, acc(train)=9.93e-01, error(valid)=8.76e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 14: 2.6s to complete
#     error(train)=1.83e-02, acc(train)=9.94e-01, error(valid)=9.27e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 15: 2.5s to complete
#     error(train)=1.99e-02, acc(train)=9.93e-01, error(valid)=9.39e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 16: 2.5s to complete
#     error(train)=2.54e-02, acc(train)=9.91e-01, error(valid)=1.14e-01, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 17: 2.5s to complete
#     error(train)=1.65e-02, acc(train)=9.94e-01, error(valid)=9.94e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 18: 2.7s to complete
#     error(train)=1.26e-02, acc(train)=9.96e-01, error(valid)=9.96e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 19: 2.6s to complete
#     error(train)=1.22e-02, acc(train)=9.96e-01, error(valid)=1.02e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 20: 2.7s to complete
#     error(train)=1.23e-02, acc(train)=9.96e-01, error(valid)=9.92e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 21: 2.4s to complete
#     error(train)=8.16e-03, acc(train)=9.98e-01, error(valid)=1.04e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 22: 2.7s to complete
#     error(train)=6.70e-03, acc(train)=9.98e-01, error(valid)=9.95e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 23: 2.5s to complete
#     error(train)=5.66e-03, acc(train)=9.99e-01, error(valid)=1.03e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 24: 2.5s to complete
#     error(train)=9.83e-03, acc(train)=9.97e-01, error(valid)=1.14e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 25: 2.5s to complete
#     error(train)=5.52e-03, acc(train)=9.98e-01, error(valid)=1.10e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 26: 2.6s to complete
#     error(train)=2.41e-03, acc(train)=9.99e-01, error(valid)=1.04e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 27: 2.7s to complete
#     error(train)=7.11e-03, acc(train)=9.98e-01, error(valid)=1.19e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 28: 2.6s to complete
#     error(train)=3.22e-03, acc(train)=9.99e-01, error(valid)=1.12e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 29: 2.6s to complete
#     error(train)=8.08e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 30: 2.6s to complete
#     error(train)=5.71e-03, acc(train)=9.98e-01, error(valid)=1.23e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 31: 2.5s to complete
#     error(train)=2.07e-02, acc(train)=9.94e-01, error(valid)=1.37e-01, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 32: 2.5s to complete
#     error(train)=1.32e-02, acc(train)=9.96e-01, error(valid)=1.21e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 33: 2.5s to complete
#     error(train)=3.71e-03, acc(train)=9.99e-01, error(valid)=1.05e-01, acc(valid)=9.80e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 34: 2.5s to complete
#     error(train)=1.06e-03, acc(train)=1.00e+00, error(valid)=1.04e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 35: 2.5s to complete
#     error(train)=5.68e-04, acc(train)=1.00e+00, error(valid)=1.02e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 36: 2.5s to complete
#     error(train)=2.90e-04, acc(train)=1.00e+00, error(valid)=1.03e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 37: 2.6s to complete
#     error(train)=2.36e-04, acc(train)=1.00e+00, error(valid)=1.05e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 38: 2.5s to complete
#     error(train)=1.87e-04, acc(train)=1.00e+00, error(valid)=1.06e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 39: 2.6s to complete
#     error(train)=1.64e-04, acc(train)=1.00e+00, error(valid)=1.07e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 40: 2.5s to complete
#     error(train)=1.47e-04, acc(train)=1.00e+00, error(valid)=1.08e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 41: 2.5s to complete
#     error(train)=1.35e-04, acc(train)=1.00e+00, error(valid)=1.09e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 42: 2.6s to complete
#     error(train)=1.24e-04, acc(train)=1.00e+00, error(valid)=1.10e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 43: 2.5s to complete
#     error(train)=1.14e-04, acc(train)=1.00e+00, error(valid)=1.11e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 44: 2.9s to complete
#     error(train)=1.06e-04, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 45: 2.7s to complete
#     error(train)=1.00e-04, acc(train)=1.00e+00, error(valid)=1.13e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 46: 2.5s to complete
#     error(train)=9.28e-05, acc(train)=1.00e+00, error(valid)=1.14e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 47: 2.5s to complete
#     error(train)=8.81e-05, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 48: 2.5s to complete
#     error(train)=8.30e-05, acc(train)=1.00e+00, error(valid)=1.15e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 49: 2.6s to complete
#     error(train)=7.87e-05, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 50: 2.5s to complete
#     error(train)=7.48e-05, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 51: 2.6s to complete
#     error(train)=7.12e-05, acc(train)=1.00e+00, error(valid)=1.17e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 52: 2.6s to complete
#     error(train)=6.81e-05, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 53: 2.5s to complete
#     error(train)=6.50e-05, acc(train)=1.00e+00, error(valid)=1.18e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 54: 2.6s to complete
#     error(train)=6.25e-05, acc(train)=1.00e+00, error(valid)=1.19e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 55: 2.6s to complete
#     error(train)=5.99e-05, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 56: 2.7s to complete
#     error(train)=5.75e-05, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 57: 2.6s to complete
#     error(train)=5.55e-05, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 58: 2.4s to complete
#     error(train)=5.34e-05, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 59: 2.5s to complete
#     error(train)=5.15e-05, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 60: 2.5s to complete
#     error(train)=4.99e-05, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 61: 2.5s to complete
#     error(train)=4.81e-05, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 62: 2.4s to complete
#     error(train)=4.67e-05, acc(train)=1.00e+00, error(valid)=1.23e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 63: 2.5s to complete
#     error(train)=4.51e-05, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 64: 3.1s to complete
#     error(train)=4.39e-05, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 65: 2.7s to complete
#     error(train)=4.24e-05, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 66: 2.8s to complete
#     error(train)=4.12e-05, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 67: 2.8s to complete
#     error(train)=4.01e-05, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 68: 2.9s to complete
#     error(train)=3.89e-05, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 69: 2.9s to complete
#     error(train)=3.79e-05, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 70: 2.6s to complete
#     error(train)=3.69e-05, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 71: 2.6s to complete
#     error(train)=3.60e-05, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 72: 3.3s to complete
#     error(train)=3.51e-05, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 73: 3.7s to complete
#     error(train)=3.42e-05, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 74: 2.9s to complete
#     error(train)=3.34e-05, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 75: 2.8s to complete
#     error(train)=3.26e-05, acc(train)=1.00e+00, error(valid)=1.28e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 76: 2.6s to complete
#     error(train)=3.18e-05, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 77: 2.6s to complete
#     error(train)=3.11e-05, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 78: 2.9s to complete
#     error(train)=3.04e-05, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 79: 2.5s to complete
#     error(train)=2.97e-05, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 80: 2.5s to complete
#     error(train)=2.91e-05, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 81: 2.5s to complete
#     error(train)=2.85e-05, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 82: 2.4s to complete
#     error(train)=2.79e-05, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 83: 2.4s to complete
#     error(train)=2.73e-05, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 84: 2.5s to complete
#     error(train)=2.68e-05, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 85: 2.5s to complete
#     error(train)=2.62e-05, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 86: 2.6s to complete
#     error(train)=2.58e-05, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 87: 2.6s to complete
#     error(train)=2.53e-05, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 88: 2.5s to complete
#     error(train)=2.48e-05, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 89: 2.6s to complete
#     error(train)=2.43e-05, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 90: 2.5s to complete
#     error(train)=2.39e-05, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 91: 2.5s to complete
#     error(train)=2.35e-05, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 92: 2.5s to complete
#     error(train)=2.30e-05, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 93: 2.6s to complete
#     error(train)=2.26e-05, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 94: 2.5s to complete
#     error(train)=2.23e-05, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 95: 2.6s to complete
#     error(train)=2.19e-05, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 96: 2.6s to complete
#     error(train)=2.15e-05, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 97: 2.7s to complete
#     error(train)=2.12e-05, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 98: 2.4s to complete
#     error(train)=2.08e-05, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 99: 2.5s to complete
#     error(train)=2.05e-05, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 100: 2.7s to complete
#     error(train)=2.02e-05, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.81e-01, params_penalty=0.00e+00

# %% [markdown]
# ## Fan-in

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# SELU

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit, UniformInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

outputlayer_weights = GlorotUniformInit(rng=rng)
weights_init = [UniformInit(-np.sqrt(3./input_dim), np.sqrt(3./input_dim), rng=rng),
                UniformInit(-np.sqrt(3./input_dim), np.sqrt(3./input_dim), rng=rng),
                UniformInit(-np.sqrt(3./input_dim), np.sqrt(3./input_dim), rng=rng),
                UniformInit(-np.sqrt(3./input_dim), np.sqrt(3./input_dim), rng=rng)]
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init[0], biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init[1], biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init[2], biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init[3], biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, outputlayer_weights, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "fanin_elu")
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 1: 1.8s to complete
#     error(train)=3.58e-01, acc(train)=8.92e-01, error(valid)=3.30e-01, acc(valid)=8.99e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 2: 1.7s to complete
#     error(train)=2.52e-01, acc(train)=9.27e-01, error(valid)=2.39e-01, acc(valid)=9.31e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 3: 1.7s to complete
#     error(train)=1.86e-01, acc(train)=9.44e-01, error(valid)=1.78e-01, acc(valid)=9.48e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 4: 1.8s to complete
#     error(train)=1.61e-01, acc(train)=9.50e-01, error(valid)=1.61e-01, acc(valid)=9.51e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 5: 1.8s to complete
#     error(train)=1.52e-01, acc(train)=9.53e-01, error(valid)=1.60e-01, acc(valid)=9.50e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 6: 1.7s to complete
#     error(train)=9.99e-02, acc(train)=9.70e-01, error(valid)=1.11e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 7: 2.1s to complete
#     error(train)=9.06e-02, acc(train)=9.73e-01, error(valid)=1.09e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 8: 2.1s to complete
#     error(train)=8.58e-02, acc(train)=9.73e-01, error(valid)=1.07e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 9: 2.3s to complete
#     error(train)=7.04e-02, acc(train)=9.79e-01, error(valid)=9.76e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 10: 2.0s to complete
#     error(train)=6.91e-02, acc(train)=9.79e-01, error(valid)=1.04e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 11: 1.7s to complete
#     error(train)=6.41e-02, acc(train)=9.81e-01, error(valid)=1.02e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 12: 2.3s to complete
#     error(train)=5.72e-02, acc(train)=9.82e-01, error(valid)=9.87e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 13: 1.8s to complete
#     error(train)=4.84e-02, acc(train)=9.86e-01, error(valid)=9.32e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 14: 1.8s to complete
#     error(train)=4.29e-02, acc(train)=9.87e-01, error(valid)=9.27e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 15: 1.8s to complete
#     error(train)=4.10e-02, acc(train)=9.87e-01, error(valid)=8.95e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 16: 1.7s to complete
#     error(train)=3.80e-02, acc(train)=9.88e-01, error(valid)=9.43e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 17: 1.6s to complete
#     error(train)=3.82e-02, acc(train)=9.88e-01, error(valid)=9.64e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 18: 1.7s to complete
#     error(train)=3.43e-02, acc(train)=9.89e-01, error(valid)=9.74e-02, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 19: 2.0s to complete
#     error(train)=2.59e-02, acc(train)=9.92e-01, error(valid)=8.74e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 20: 1.8s to complete
#     error(train)=2.23e-02, acc(train)=9.94e-01, error(valid)=9.16e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 21: 1.8s to complete
#     error(train)=2.34e-02, acc(train)=9.93e-01, error(valid)=9.45e-02, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 22: 1.8s to complete
#     error(train)=2.60e-02, acc(train)=9.91e-01, error(valid)=1.06e-01, acc(valid)=9.73e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 23: 2.0s to complete
#     error(train)=2.37e-02, acc(train)=9.92e-01, error(valid)=9.76e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 24: 1.8s to complete
#     error(train)=1.69e-02, acc(train)=9.95e-01, error(valid)=9.44e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 25: 1.8s to complete
#     error(train)=1.37e-02, acc(train)=9.96e-01, error(valid)=9.37e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 26: 1.7s to complete
#     error(train)=1.20e-02, acc(train)=9.97e-01, error(valid)=9.57e-02, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 27: 1.6s to complete
#     error(train)=1.29e-02, acc(train)=9.96e-01, error(valid)=9.94e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 28: 1.7s to complete
#     error(train)=1.45e-02, acc(train)=9.96e-01, error(valid)=1.05e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 29: 1.6s to complete
#     error(train)=9.20e-03, acc(train)=9.98e-01, error(valid)=1.01e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 30: 1.7s to complete
#     error(train)=1.39e-02, acc(train)=9.95e-01, error(valid)=1.15e-01, acc(valid)=9.74e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 31: 1.6s to complete
#     error(train)=1.78e-02, acc(train)=9.94e-01, error(valid)=1.17e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 32: 1.6s to complete
#     error(train)=1.40e-02, acc(train)=9.95e-01, error(valid)=1.14e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 33: 1.6s to complete
#     error(train)=4.66e-03, acc(train)=9.99e-01, error(valid)=1.05e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 34: 1.6s to complete
#     error(train)=1.04e-02, acc(train)=9.97e-01, error(valid)=1.20e-01, acc(valid)=9.75e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 35: 1.6s to complete
#     error(train)=5.02e-03, acc(train)=9.99e-01, error(valid)=1.12e-01, acc(valid)=9.76e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 36: 1.6s to complete
#     error(train)=2.64e-03, acc(train)=1.00e+00, error(valid)=1.12e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 37: 1.7s to complete
#     error(train)=2.97e-03, acc(train)=9.99e-01, error(valid)=1.16e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 38: 1.7s to complete
#     error(train)=2.10e-03, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 39: 1.7s to complete
#     error(train)=1.80e-03, acc(train)=1.00e+00, error(valid)=1.16e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 40: 1.8s to complete
#     error(train)=1.48e-03, acc(train)=1.00e+00, error(valid)=1.20e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 41: 1.6s to complete
#     error(train)=3.10e-03, acc(train)=9.99e-01, error(valid)=1.27e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 42: 1.7s to complete
#     error(train)=9.79e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.77e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 43: 1.6s to complete
#     error(train)=1.20e-03, acc(train)=1.00e+00, error(valid)=1.22e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 44: 1.6s to complete
#     error(train)=8.73e-04, acc(train)=1.00e+00, error(valid)=1.21e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 45: 1.7s to complete
#     error(train)=6.17e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 46: 1.6s to complete
#     error(train)=5.32e-04, acc(train)=1.00e+00, error(valid)=1.24e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 47: 1.6s to complete
#     error(train)=4.76e-04, acc(train)=1.00e+00, error(valid)=1.25e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 48: 1.6s to complete
#     error(train)=4.52e-04, acc(train)=1.00e+00, error(valid)=1.26e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 49: 1.6s to complete
#     error(train)=4.10e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 50: 1.6s to complete
#     error(train)=3.88e-04, acc(train)=1.00e+00, error(valid)=1.27e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 51: 1.7s to complete
#     error(train)=3.48e-04, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 52: 1.6s to complete
#     error(train)=3.28e-04, acc(train)=1.00e+00, error(valid)=1.29e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 53: 2.5s to complete
#     error(train)=3.14e-04, acc(train)=1.00e+00, error(valid)=1.30e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 54: 2.1s to complete
#     error(train)=3.07e-04, acc(train)=1.00e+00, error(valid)=1.31e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 55: 1.9s to complete
#     error(train)=2.82e-04, acc(train)=1.00e+00, error(valid)=1.32e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 56: 1.6s to complete
#     error(train)=2.76e-04, acc(train)=1.00e+00, error(valid)=1.33e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 57: 1.6s to complete
#     error(train)=2.57e-04, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 58: 1.6s to complete
#     error(train)=2.47e-04, acc(train)=1.00e+00, error(valid)=1.34e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 59: 1.6s to complete
#     error(train)=2.50e-04, acc(train)=1.00e+00, error(valid)=1.35e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 60: 1.7s to complete
#     error(train)=2.37e-04, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 61: 1.6s to complete
#     error(train)=2.21e-04, acc(train)=1.00e+00, error(valid)=1.36e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 62: 1.6s to complete
#     error(train)=2.11e-04, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 63: 1.6s to complete
#     error(train)=2.00e-04, acc(train)=1.00e+00, error(valid)=1.37e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 64: 1.6s to complete
#     error(train)=2.02e-04, acc(train)=1.00e+00, error(valid)=1.38e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 65: 1.6s to complete
#     error(train)=1.88e-04, acc(train)=1.00e+00, error(valid)=1.39e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 66: 2.0s to complete
#     error(train)=1.86e-04, acc(train)=1.00e+00, error(valid)=1.39e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 67: 2.0s to complete
#     error(train)=1.78e-04, acc(train)=1.00e+00, error(valid)=1.39e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 68: 2.0s to complete
#     error(train)=1.70e-04, acc(train)=1.00e+00, error(valid)=1.40e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 69: 1.8s to complete
#     error(train)=1.67e-04, acc(train)=1.00e+00, error(valid)=1.40e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 70: 1.6s to complete
#     error(train)=1.60e-04, acc(train)=1.00e+00, error(valid)=1.41e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 71: 1.8s to complete
#     error(train)=1.58e-04, acc(train)=1.00e+00, error(valid)=1.42e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 72: 1.7s to complete
#     error(train)=1.54e-04, acc(train)=1.00e+00, error(valid)=1.42e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 73: 1.6s to complete
#     error(train)=1.49e-04, acc(train)=1.00e+00, error(valid)=1.43e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 74: 1.6s to complete
#     error(train)=1.44e-04, acc(train)=1.00e+00, error(valid)=1.43e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 75: 1.6s to complete
#     error(train)=1.39e-04, acc(train)=1.00e+00, error(valid)=1.44e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 76: 1.6s to complete
#     error(train)=1.35e-04, acc(train)=1.00e+00, error(valid)=1.44e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 77: 1.6s to complete
#     error(train)=1.33e-04, acc(train)=1.00e+00, error(valid)=1.44e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 78: 1.6s to complete
#     error(train)=1.33e-04, acc(train)=1.00e+00, error(valid)=1.45e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 79: 1.6s to complete
#     error(train)=1.28e-04, acc(train)=1.00e+00, error(valid)=1.45e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 80: 1.6s to complete
#     error(train)=1.23e-04, acc(train)=1.00e+00, error(valid)=1.46e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 81: 1.6s to complete
#     error(train)=1.20e-04, acc(train)=1.00e+00, error(valid)=1.46e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 82: 1.6s to complete
#     error(train)=1.18e-04, acc(train)=1.00e+00, error(valid)=1.46e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 83: 1.6s to complete
#     error(train)=1.15e-04, acc(train)=1.00e+00, error(valid)=1.47e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 84: 1.6s to complete
#     error(train)=1.13e-04, acc(train)=1.00e+00, error(valid)=1.48e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 85: 1.6s to complete
#     error(train)=1.10e-04, acc(train)=1.00e+00, error(valid)=1.47e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 86: 1.6s to complete
#     error(train)=1.08e-04, acc(train)=1.00e+00, error(valid)=1.48e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 87: 1.6s to complete
#     error(train)=1.05e-04, acc(train)=1.00e+00, error(valid)=1.49e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 88: 1.6s to complete
#     error(train)=1.03e-04, acc(train)=1.00e+00, error(valid)=1.49e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 89: 1.6s to complete
#     error(train)=1.01e-04, acc(train)=1.00e+00, error(valid)=1.49e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 90: 1.6s to complete
#     error(train)=9.94e-05, acc(train)=1.00e+00, error(valid)=1.49e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 91: 1.6s to complete
#     error(train)=9.97e-05, acc(train)=1.00e+00, error(valid)=1.50e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 92: 1.6s to complete
#     error(train)=9.53e-05, acc(train)=1.00e+00, error(valid)=1.51e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 93: 1.6s to complete
#     error(train)=9.28e-05, acc(train)=1.00e+00, error(valid)=1.50e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 94: 1.6s to complete
#     error(train)=9.21e-05, acc(train)=1.00e+00, error(valid)=1.51e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 95: 1.6s to complete
#     error(train)=9.03e-05, acc(train)=1.00e+00, error(valid)=1.51e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 96: 1.6s to complete
#     error(train)=8.78e-05, acc(train)=1.00e+00, error(valid)=1.51e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 97: 1.6s to complete
#     error(train)=8.65e-05, acc(train)=1.00e+00, error(valid)=1.51e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 98: 1.6s to complete
#     error(train)=8.50e-05, acc(train)=1.00e+00, error(valid)=1.52e-01, acc(valid)=9.78e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 99: 1.6s to complete
#     error(train)=8.34e-05, acc(train)=1.00e+00, error(valid)=1.52e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 100: 1.6s to complete
#     error(train)=8.29e-05, acc(train)=1.00e+00, error(valid)=1.53e-01, acc(valid)=9.79e-01, params_penalty=0.00e+00

# %% [markdown]
# ## Fan-out

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# SELU

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

outputlayer_weights = GlorotUniformInit(rng=rng)
weights_init = [UniformInit(-np.sqrt(3./output_dim), np.sqrt(3./output_dim), rng=rng),
                UniformInit(-np.sqrt(3./output_dim), np.sqrt(3./output_dim), rng=rng),
                UniformInit(-np.sqrt(3./output_dim), np.sqrt(3./output_dim), rng=rng),
                UniformInit(-np.sqrt(3./output_dim), np.sqrt(3./output_dim), rng=rng)]
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init[0], biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init[1], biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init[2], biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init[3], biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, outputlayer_weights, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "fanout_elu")
# Out:
# HBox(children=(IntProgress(value=0), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# /Users/adriancristea/Documents/University Files/4th Year/MLP/mlp/mlp/errors.py:171: RuntimeWarning: overflow encountered in exp
#   probs = np.exp(outputs)
# /Users/adriancristea/Documents/University Files/4th Year/MLP/mlp/mlp/errors.py:172: RuntimeWarning: invalid value encountered in true_divide
#   probs /= probs.sum(-1)[:, None]
# /Users/adriancristea/Documents/University Files/4th Year/MLP/mlp/mlp/layers.py:356: RuntimeWarning: invalid value encountered in less_equal
#   outputs = np.where(inputs <= 0,
# /Users/adriancristea/Documents/University Files/4th Year/MLP/mlp/mlp/layers.py:368: RuntimeWarning: invalid value encountered in less_equal
#   gradients = np.where(outputs <= 0,
# Epoch 1: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 2: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 3: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 4: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 5: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 6: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
# Epoch 7: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02, params_penalty=0.00e+00
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))

# %% [markdown]
# ## Fan-in and Fan-out

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# SELU

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "faninout_elu")

# %% [markdown]
# ## SELU with Gaussian Initialisation

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

# SELU

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = SELUInit(rng=rng)
biases_init = ConstantInit(0.)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])

error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

#Remember to use notebook=False when you write a script to be run in a terminal
_ = train_model_and_plot_stats(
    model, error, learning_rule, 
    train_data, valid_data, num_epochs, stats_interval, 
    notebook=True, fig_name = "gaussian_selu")
